# %%
from functools import partial
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from tqdm import tqdm
import nltk
import torch, torchhd
import torchtext.datasets as datasets
from torch.utils.data import DataLoader
nltk.download('punkt')

from utils import WikiTextDatasetPrev
# Out:
# [nltk_data] Downloading package punkt to /home/senn/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import sys
sys.path.append('..')
from shared_code.helpers import similarity_func_partial, top_k_vectors

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ## This preprocessing step needs to be done only once for each dataset

# %%
wiki_dataset = "wikitext-2-v1"
# wiki_dataset = "wikitext-103-v1"
data_path = './data/' + wiki_dataset + '/train-00000-of-00001.parquet'
out_dir = './data/preprocessed/' + wiki_dataset

wiki_text_dataset = WikiTextDatasetPrev(data_path, out_dir)
# Out:
# 36718it [01:04, 565.32it/s]

# %% [markdown]
# ### Load the preprocessed data

# %%
# load the preprocessed data in a term-document matrix using scikit-learn
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import os
count_vectorizer = CountVectorizer(token_pattern=r'[\w<>]+', input='filename')
# use file iterator over files in out_dir to avoid loading all data into memory
# input files are all txt files in out_dir
files = [file for file in os.listdir(out_dir) if file.endswith('.txt')]

print(len(files))

input_files = [out_dir + '/' + file for file in files]
print(input_files)
doc_term_matrix = count_vectorizer.fit_transform(input_files)
# Out:
# 603
# ['./data/preprocessed/wikitext-2-v1/Back_to_Tennessee_(_song_).txt', './data/preprocessed/wikitext-2-v1/Rob_Howard.txt', './data/preprocessed/wikitext-2-v1/2011_–_12_Columbus_Blue_Jackets_season.txt', './data/preprocessed/wikitext-2-v1/Xenon.txt', './data/preprocessed/wikitext-2-v1/Texas_A_&_M_Singing_Cadets.txt', './data/preprocessed/wikitext-2-v1/Grammy_Award_for_Best_Concept_Music_Video.txt', './data/preprocessed/wikitext-2-v1/Jenova_Chen.txt', './data/preprocessed/wikitext-2-v1/Hoyt_Wilhelm.txt', './data/preprocessed/wikitext-2-v1/Chapter_1_(_House_of_Cards_).txt', './data/preprocessed/wikitext-2-v1/WASP_@-@_44.txt', './data/preprocessed/wikitext-2-v1/<unk>___<unk>_,_Pts.txt', './data/preprocessed/wikitext-2-v1/Isabella_Beeton.txt', './data/preprocessed/wikitext-2-v1/Hurricane_Lorenzo_(_2007_).txt', './data/preprocessed/wikitext-2-v1/Yoko_Shimomura.txt', './data/preprocessed/wikitext-2-v1/Stuart_McCall.txt', './data/preprocessed/wikitext-2-v1/Not_Quite_Hollywood_:_The_Wild_,_Untold_Story_of_Ozploitation_!.txt', './data/preprocessed/wikitext-2-v1/Big_Boy_(_song_).txt', './data/preprocessed/wikitext-2-v1/Arikamedu.txt', './data/preprocessed/wikitext-2-v1/John_Cullen.txt', './data/preprocessed/wikitext-2-v1/Nicole_Franklin.txt', './data/preprocessed/wikitext-2-v1/The_Boat_Race_1999.txt', './data/preprocessed/wikitext-2-v1/Crash_Boom_Bang_!.txt', './data/preprocessed/wikitext-2-v1/Simon_Bradstreet.txt', './data/preprocessed/wikitext-2-v1/Grade_I_listed_buildings_in_Somerset.txt', './data/preprocessed/wikitext-2-v1/Coldrum_Long_Barrow.txt', './data/preprocessed/wikitext-2-v1/Toronto_Magnetic_and_Meteorological_Observatory.txt', './data/preprocessed/wikitext-2-v1/Réunion_ibis.txt', './data/preprocessed/wikitext-2-v1/Caught_Up_(_Usher_song_).txt', './data/preprocessed/wikitext-2-v1/Mark_Stockwell.txt', './data/preprocessed/wikitext-2-v1/Forward_Intelligence_Team.txt', './data/preprocessed/wikitext-2-v1/Verpa_bohemica.txt', './data/preprocessed/wikitext-2-v1/A_Month_in_the_Country_(_film_).txt', './data/preprocessed/wikitext-2-v1/Roxas_(_Kingdom_Hearts_).txt', './data/preprocessed/wikitext-2-v1/Memory_Almost_Full.txt', './data/preprocessed/wikitext-2-v1/Art_in_Medieval_Scotland.txt', './data/preprocessed/wikitext-2-v1/Chagas_disease.txt', './data/preprocessed/wikitext-2-v1/Elgin_Cathedral.txt', './data/preprocessed/wikitext-2-v1/Battle_of_Binh_<unk>.txt', './data/preprocessed/wikitext-2-v1/Ceres_(_dwarf_planet_).txt', "./data/preprocessed/wikitext-2-v1/Burns_'_Heir.txt", "./data/preprocessed/wikitext-2-v1/You_'re_Gonna_Love_Tomorrow.txt", './data/preprocessed/wikitext-2-v1/Partington.txt', "./data/preprocessed/wikitext-2-v1/Ha_'_K_'in_Xook.txt", './data/preprocessed/wikitext-2-v1/Italian_cruiser_Aretusa.txt', './data/preprocessed/wikitext-2-v1/Wales_national_rugby_union_team.txt', './data/preprocessed/wikitext-2-v1/S_R__819.txt', './data/preprocessed/wikitext-2-v1/Trees_(_poem_).txt', './data/preprocessed/wikitext-2-v1/Boise_National_Forest.txt', './data/preprocessed/wikitext-2-v1/Liu_Kang.txt', './data/preprocessed/wikitext-2-v1/Mozambican_War_of_Independence.txt', './data/preprocessed/wikitext-2-v1/Ode_on_Indolence.txt', './data/preprocessed/wikitext-2-v1/The_Tempest_(_album_).txt', './data/preprocessed/wikitext-2-v1/U2_concert_in_Sarajevo.txt', './data/preprocessed/wikitext-2-v1/The_Litigators.txt', './data/preprocessed/wikitext-2-v1/Elephanta_Caves.txt', './data/preprocessed/wikitext-2-v1/Bob_Dylan.txt', './data/preprocessed/wikitext-2-v1/No__79_Wing_RAAF.txt', './data/preprocessed/wikitext-2-v1/Stanley_Green.txt', './data/preprocessed/wikitext-2-v1/Khoo_<unk>_@-@_<unk>.txt', './data/preprocessed/wikitext-2-v1/The_Moth_(_Lost_).txt', './data/preprocessed/wikitext-2-v1/Ouw_Peh_Tjoa.txt', './data/preprocessed/wikitext-2-v1/Kaboom_(_Parks_and_Recreation_).txt', './data/preprocessed/wikitext-2-v1/Washington_State_Route_221.txt', './data/preprocessed/wikitext-2-v1/Typhoon_Imbudo.txt', './data/preprocessed/wikitext-2-v1/HMS_Comet_(_ ...

# %%
print(doc_term_matrix.shape)
# Out:
# (603, 27068)

# %%
# print(f'Number of documents: {len(wiki_text_dataset)}')
# print(f'Title of first document: {wiki_text_dataset[0].title}')
# print(f'First 10 words of first document: {wiki_text_dataset[0].text[:10]}')
# print(f'Length of first document: {len(wiki_text_dataset[0].text)}')
# print(f'Number of elements in vocabulary of first document: {len(wiki_text_dataset[0].vocabulary)}')
print(f'Number of elements in the vocabulary: {len(wiki_text_dataset.vocabulary)}')

# print(f'Number of documents: {doc_term_matrix.shape[0]}')
# print(f'Vocab: {count_vectorizer.get_feature_names_out()[:10]}')
# print(f'Number of elements in the vocabulary: {len(count_vectorizer.vocabulary_)}')
# print(f'Lenght of the first document: {doc_term_matrix[0].sum()}')
# Out:
# Number of elements in the vocabulary: 27103

# %% [markdown]
# ### Onto HD Vectors

# %%
DIMENSIONS = 10_000
vocab_size = len(wiki_text_dataset.vocabulary)
vsa_type= 'MAP'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using {} device".format(device))
sim_func = partial(similarity_func_partial, vsa_type)
# Out:
# Using cuda device

# %% [markdown]
# ### Creating the document embeddings to learn from the data

# %%
# label_embeddings = torchhd.random(vocab_size, DIMENSIONS, device=device, vsa=vsa_type)
document_embeddings = torchhd.random(len(wiki_text_dataset), DIMENSIONS, device=device, vsa=vsa_type)
learned_embeddings = torchhd.empty(vocab_size, DIMENSIONS, device=device, vsa=vsa_type)

# %%
for doc_idx, document in enumerate(tqdm(wiki_text_dataset)):
    document_embedding = document_embeddings[doc_idx]
    for word in document.vocabulary.idx2word:
        word_idx = wiki_text_dataset.vocabulary.word2idx[word] # wrong
        # word_embedding = label_embeddings[word_idx]
        learned_embeddings[word_idx] = learned_embeddings[word_idx].bundle(document_embedding) # Bundle is not in-place
# Out:
# 100%|██████████| 609/609 [00:34<00:00, 17.42it/s]

# %%
# normalize the learned embeddings
# for idx in range(len(learned_embeddings)):
#     learned_embeddings[idx] = learned_embeddings[idx].clipping(1)
learned_embeddings = torchhd.hard_quantize(learned_embeddings)
# print(learned_embeddings)

# %%
# are there empty embeddings?
for idx in range(len(learned_embeddings)):
    if torch.all(learned_embeddings[idx] == 0):
        print(f'Empty embedding at index {idx}')

# %%
def plot_k_most_similar_words(reference_word, memory, k=10, vocabulary=wiki_text_dataset.vocabulary):
    word_idx = vocabulary.word2idx[reference_word]
    word_vector = memory[word_idx]
    # get the k most similar words to the reference word, remove the reference word from the result
    similarities, similar_vector_idxs = top_k_vectors(word_vector, memory, k+1, vsa_type)
    # remove the reference word from the result
    similarities = similarities[1:]
    similar_vector_idxs = similar_vector_idxs[1:]
    
    similar_words = [vocabulary.idx2word[idx] for idx in similar_vector_idxs]
    # bar plot using plotly express
    fig = px.bar(x=similar_words, y=similarities.cpu().numpy(), title=f"Most similar words to {reference_word}", labels={'x': 'Word', 'y': 'Similarity'})
    fig.update_xaxes(tickangle=-45)
    fig.show()

# %%
reference_word = "movie"

plot_k_most_similar_words(reference_word, learned_embeddings, k=15)
# Out:
# <div>                            <div id="7d8e72ce-8cd8-43c0-aabf-1cddb97c7cdd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d8e72ce-8cd8-43c0-aabf-1cddb97c7cdd")) {                    Plotly.newPlot(                        "7d8e72ce-8cd8-43c0-aabf-1cddb97c7cdd",                        [{"alignmentgroup":"True","hovertemplate":"Word=%{x}\u003cbr\u003eSimilarity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["film","plot","films","directed","hollywood","actors","character","video","entertainment","cast","reception","movies","producer","tries","hired"],"xaxis":"x","y":[0.35580000281333923,0.3061999976634979,0.3027999997138977,0.2994000017642975,0.29899999499320984,0.28600001335144043,0.28380000591278076,0.28060001134872437,0.2766000032424927,0.2687999904155731,0.26739999651908875,0.2669999897480011,0.26579999923706055,0.26339998841285706,0.26260000467300415],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpol ...

# %% [markdown]
# ### similarity of random vocabulary word to other words in the vocabulary

# %%
reference_vector = learned_embeddings[wiki_text_dataset.vocabulary.word2idx[reference_word]]
similarities = sim_func(reference_vector, learned_embeddings)
similarities_cpu = similarities.cpu().numpy()
similarities_sorted = np.sort(similarities_cpu)[::-1]
# count amount of similarities above .3
similarities_above_threshold = similarities_cpu[similarities_cpu > .3]
print(f'Number of similarities above .3: {len(similarities_above_threshold)-1}')
# Out:
# Number of similarities above .3: 3

# %%
# plot similarity distribution using plotly express
fig = px.histogram(x=similarities.cpu().numpy(), title=f"Similarity distribution of word {reference_word} to all other words in vocabulary", labels={'x': 'Similarity', 'y': 'Frequency'})
fig.update_xaxes(range=[-.1, .5])
fig.show()
# Out:
# <div>                            <div id="29049c4f-ab35-4c85-8cdf-c90ef9fe7a47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29049c4f-ab35-4c85-8cdf-c90ef9fe7a47")) {                    Plotly.newPlot(                        "29049c4f-ab35-4c85-8cdf-c90ef9fe7a47",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Similarity=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[-0.016200000420212746,-0.016200000420212746,0.21539999544620514,0.10679999738931656,0.13019999861717224,0.03759999945759773,0.0142000000923872,0.052000001072883606,0.12300000339746475,0.05999999865889549,0.08299999684095383,0.1120000034570694,0.017000000923871994,0.22579999268054962,0.24320000410079956,0.28060001134872437,0.17399999499320984,0.09399999678134918,0.00419999985024333,0.07180000096559525,0.01140000019222498,0.2295999974012375,0.13779999315738678,0.1712000072002411,0.21160000562667847,0.08420000225305557,0.251800000667572,0.2125999927520752,0.05000000074505806,0.028200000524520874,0.24639999866485596,0.07500000298023224,0.03020000085234642,0.21140000224113464,0.06419999897480011,-0.016200000420212746,-0.006599999964237213,0.05860000103712082,0.05939999967813492,0.08479999750852585,0.10320000350475311,-0.016200000420212746,0.1899999976158142,0.007400000002235174,0.10999999940395355,0.07680000364780426,0.1477999985218048,0.1501999944448471,0.04280000180006027,-0.00279999990016222,0.0414000004529953,-0.007600000128149986,0.1712000072002411,0.14419999718666077,0.04320000112056732,0.1143999993801117,0.06340000033378601,0.23180000483989716,0.17399999499320984,0.10400000214576721,0.058400001376867294,0.1298000067472458,0.17399999499320984,0.2085999995470047,0.08460000157356262,0.0860000029206276,-0.009600000455975533,0.1817999929189682,0.008200000040233135,0.28380000591278076,0.11620000004768372,-0.016200000420212746,0.12620000541210175,-0.0017999999690800905,-0.016200000420212746,0.13459999859333038,0.15160000324249268,0.015799999237060547,0.1664000004529953,0.22920000553131104,-0.01600000075995922,-0.016200000420212746,0.14880000054836273,0.17080000042915344,0.08460000157356262,0.23319999873638153,0.16779999434947968,0.19660000503063202,0.10520000010728836,0.18400000035762787,0.1316000074148178,0.23759999871253967,0.1451999992132187,0.15539999306201935,0.09019999951124191,0.23839999735355377,0.2248000055551529,0.23019999265670776,0.015799999237060547,0.08579999953508377,0.06260000169277191,0.13860000669956207,0.16539999842643738,0.20020000636577606,0.1436000019311905,0.05040000006556511,0.23759999871253967,0.13660000264644623,0.164000004529953,0.07079999893903732,-0.03420000150799751,0.1501999944448471,0.04340000078082085,0.012400000356137753,0.2101999968290329,0.17659999430179596,0.07819999754428864,-0.0017999999690800905,0.0689999982714653,0.1306000053882599,0.06159999966621399,0.19300000369548798,0.14020000398159027,0.19920000433921814,0.04479999840259552,0.08560000360012054,0.1379999965429306,0.1459999978542328,0.24480000138282776,0.15719999372959137,0.2303999960422516,0.25440001487731934,0.05779999867081642,0.14380000531673431,0.04619999974966049,0.23420000076293945,0.1324000060558319,0.04580000042915344,0.08500000089406967,0.07199999690055847,-0.00800000037997961,0.030799999833106995,0.10260000079870224,0.03319999948143959,0.04859999939799309,0.0828000009059906,-0.02539999969303608,0.03579999879002571,0.028999999165534973,0.007600000128149986,0.06920000165700912,0.09839999675750732,0.11060000211000443,0.005799999926239252,0.07580000162124634,0.06340000033378601,0.13740000128746033,0.21879999339580536,0.08579999953508377,0. ...

# %% [markdown]
# ### Wordsim353 validation

# %%
from utils import Wordsim353Loader
    
wordsim353_loader = Wordsim353Loader("../../data_external/wordsim353/wordsim_relatedness_goldstandard.txt")
print(f"Number of word pairs: {len(wordsim353_loader)}")
print(f"First word pair: {wordsim353_loader[0]}")

wordsim_learned_similarities = []

for word1, word2, score in tqdm(wordsim353_loader):
    if word1 not in wiki_text_dataset.vocabulary.word2idx or word2 not in wiki_text_dataset.vocabulary.word2idx:
        continue
    word1_idx = wiki_text_dataset.vocabulary.word2idx[word1]
    word2_idx = wiki_text_dataset.vocabulary.word2idx[word2]
    word1_vector = learned_embeddings[word1_idx]
    word2_vector = learned_embeddings[word2_idx]
    similarity = sim_func(word1_vector, word2_vector)
    wordsim_learned_similarities.append((word1, word2, similarity.item(), float(score)))

print(f"First 10 similarities:")
for word1, word2, sim, score in wordsim_learned_similarities[:10]:
    tab_size = word1 + word2
    tab_size = 20 - len(tab_size)
    print(f"{word1} - {word2} {tab_size * ' '} {round(sim, 3)} \t {round(score, 3)}")

corr = np.corrcoef([sim for _, _, sim, _ in wordsim_learned_similarities], [score for _, _, _, score in wordsim_learned_similarities])
print(f"Correlation between learned similarities and human scores: {corr[0, 1]}")
# Out:
# Number of word pairs: 252
# First word pair: ['computer', 'keyboard', '7.62']
# 100%|██████████| 252/252 [00:00<00:00, 1626.94it/s]
# First 10 similarities:
# computer - keyboard      0.034 	 7.62
# planet - galaxy          0.108 	 8.11
# canyon - landscape       0.148 	 7.53
# day - summer             0.285 	 3.94
# day - dawn               0.157 	 7.53
# country - citizen        0.101 	 7.31
# planet - people          0.084 	 5.75
# environment - ecology    0.088 	 8.81
# money - bank             0.143 	 8.5
# computer - software      0.32 	 8.5
# Correlation between learned similarities and human scores: 0.25971405480116705

# %%
wiki_text_dataset.get_word_frequency(reference_word, document_frequency=True)
# Out:
# 63

# %% [markdown]
# ### Avg similarity vs frequency in documents

# %%
import pandas as pd

avg_similarities = []
random_idxs = np.random.choice(range(len(wiki_text_dataset.vocabulary)), size=1000, replace=False)
df_avg_similarities = pd.DataFrame(columns=["word", "doc_freq", "avg_similarity"])

for word_idx in tqdm(random_idxs):
  word = wiki_text_dataset.vocabulary.idx2word[word_idx]
  word_vector = learned_embeddings[word_idx]

  word_doc_freq = wiki_text_dataset.get_word_frequency(word, document_frequency=True)
  similarities = sim_func(word_vector, learned_embeddings)
  avg_similarity = similarities.mean().item()
  avg_similarities.append((word_doc_freq, avg_similarity, word))

# Convert avg_similarities into a DataFrame
df_avg_similarities = pd.DataFrame(avg_similarities, columns=['Word Document Frequency', 'Average Similarity', 'Word'])
# Out:
# 100%|██████████| 1000/1000 [00:36<00:00, 27.45it/s]

# %%
# scatter plot using plotly express
# fig = px.scatter(x=[x for x, _ in avg_similarities], y=[y for _, y in avg_similarities], title=f"Average similarity of 1000 vocabulary words vs the word document frequency", labels={'x': 'Word document frequency', 'y': 'Average similarity to all other learned embeddings'})
fig = px.scatter(df_avg_similarities, x='Word Document Frequency', y='Average Similarity', title=f"Average similarity of 1000 vocabulary words vs the word document frequency", labels={'x': 'Word document frequency', 'y': 'Average similarity to all other learned embeddings'}, hover_data=['Word'])
fig.show()
# Out:
# <div>                            <div id="923e0ece-70c4-4371-b399-d457fa6be8c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("923e0ece-70c4-4371-b399-d457fa6be8c2")) {                    Plotly.newPlot(                        "923e0ece-70c4-4371-b399-d457fa6be8c2",                        [{"customdata":[["spark"],["pulled"],["renewed"],["regret"],["enterprise"],["advanced"],["kurstin"],["reaching"],["nourished"],["monophyletic"],["cardinals"],["babylon"],["bethe"],["jet"],["tribe"],["congregation"],["innovations"],["esque"],["lets"],["wca"],["pens"],["muscled"],["replay"],["expended"],["targeted"],["acres"],["crusaders"],["merging"],["retaining"],["reader"],["minimal"],["supplemented"],["hooper"],["trouble"],["anfield"],["si\u00e8cle"],["bernissartensis"],["balloons"],["released"],["mac"],["ludlow"],["fluorescent"],["prequel"],["sociology"],["teng"],["insulted"],["supervision"],["dishonest"],["symptoms"],["competence"],["mushroom"],["protocol"],["cgt"],["venice"],["portray"],["currency"],["related"],["paint"],["kosb"],["roush"],["chong"],["waterfront"],["banished"],["restlessness"],["castro"],["ferraris"],["absorbs"],["disapproved"],["pelts"],["irresistible"],["stout"],["loyalties"],["settlements"],["careers"],["lieutenant"],["talented"],["metaphorical"],["dressings"],["resolved"],["brothers"],["jain"],["hanoi"],["reputed"],["mountings"],["refreshingly"],["prompting"],["functional"],["interwoven"],["appealing"],["introducing"],["plans"],["myeloproliferative"],["silt"],["nots"],["stingray"],["authorship"],["nhl"],["rifle"],["emulation"],["kisses"],["residues"],["legs"],["bowman"],["appoints"],["fibrils"],["warns"],["orilla"],["gravestone"],["reductions"],["analysed"],["unsuited"],["estimating"],["scripts"],["coalition"],["bereft"],["ensemble"],["cabbage"],["persuading"],["duat"],["numismatic"],["abbreviation"],["casing"],["jesuit"],["handel"],["eye"],["bafta"],["antagonist"],["transjordan"],["foyle"],["ibotenic"],["pandit"],["margaret"],["roddick"],["soir"],["qui"],["weevil"],["bradley"],["grandchildren"],["worse"],["parole"],["computed"],["factors"],["colletts"],["whim"],["decimated"],["ripley"],["localised"],["souvenirs"],["sitriuc"],["mughal"],["temporal"],["rectory"],["credited"],["boasted"],["denton"],["reconstruct"],["hailing"],["station"],["se\u00f1ora"],["cookery"],["centimeters"],["observers"],["programming"],["blueprints"],["ash"],["respectability"],["nationality"],["gerry"],["transfer"],["wansel"],["artistic"],["belief"],["guards"],["treat"],["precise"],["saying"],["jurors"],["busiest"],["microsoft"],["nearer"],["ifpi"],["archdeacon"],["accountants"],["unfamiliar"],["considerably"],["sure"],["oscar"],["aired"],["died"],["oppidum"],["usurpers"],["yew"],["counted"],["falsified"],["irvine"],["neural"],["sefik"],["youth"],["roads"],["yield"],["consort"],["deposited"],["driven"],["malalas"],["disarmed"],["gacy"],["particularly"],["go\u00e2ve"],["negation"],["recognise"],["thinner"],["pathogens"],["clerics"],["simulator"],["dimer"],["technologically"],["layne"],["satisfy"],["salim"],["unjustly"],["millions"],["poppy"],["average"],["closer"],["analysis"],["angled"],["rides"],["narrator"],["henson"],["edges"],["ottomans"],["luminous"],["prasad"],["chure"],["trevor"],["health"],["kang"],["tasmanian"],["stressed"],["emphatically"],["sphinx"],["advertised"],["pullo"],["studios"],["barium"],["flightlessness"],["prepare"],["uptake"],["opening"],["medium"],["listeners"],["hydnoid"],["resign"],["archaic"],["blaine"],["drag"],["transcribed"],["f\u00e9lix"],["untrained"],["adequately"],["evocation"],["nanobot"],["coasts"],["skimpy"],["prefers"],["unity"],["recipes"],["nesting"],["decreased"],["flapping"],["jackson"],["tree"],["textbook"],["love"],["originator"],["spiegelman"],["photographs"],["est ...

# %%
target_word = 'coordinates'
# print document frequency of target word
print(f"Document frequency of word {target_word}: {wiki_text_dataset.get_word_frequency(target_word, document_frequency=True)}")
# Out:
# Document frequency of word coordinates: 4

# %% [markdown]
# ## LSA

# %%
# vocab_idx_mapping = {word: idx for idx, word in enumerate(wiki_text_dataset.vocabulary.idx2word)}
# also match < and >
count_vectorizer = CountVectorizer(vocabulary=wiki_text_dataset.vocabulary.idx2word, token_pattern=r'[\w<>]+')
doc_term_matrix = count_vectorizer.fit_transform([' '.join(doc.text) for doc in wiki_text_dataset])

# %%
print(wiki_text_dataset.vocabulary.idx2word[:10])
# 3 first 10 keys of the vocabulary
print(count_vectorizer.get_feature_names_out()[:10])
print(doc_term_matrix.shape)
# print(doc_term_matrix[:10, :10].todense())
# Out:
# ['senjō', 'valkyria', '<num>', 'chronicles', 'japanese', 'lit', 'battlefield', 'commonly', 'referred', 'iii']
# ['senjō' 'valkyria' '<num>' 'chronicles' 'japanese' 'lit' 'battlefield'
#  'commonly' 'referred' 'iii']
# (609, 27103)

# %%
# get the word frequency of the reference word
reference_word = "times"
reference_word_idx = wiki_text_dataset.vocabulary.word2idx[reference_word]
word_doc_freq = doc_term_matrix[:, reference_word_idx].sum()
print(f"Term frequency of the word {reference_word}: {word_doc_freq}")

first_doc_length = len(wiki_text_dataset[0].text)
print(f"Length of first document: {first_doc_length}")
print(f"Number of words in the first document: {len(wiki_text_dataset[0].vocabulary)}")
print(f"Number of words according to the count vectorizer: {doc_term_matrix[-1].sum()}")
print(f"Number of documents the word appears in according to the count vectorizer, use the non-zero elements of the column: {doc_term_matrix[-1].count_nonzero()}")
# Out:
# Term frequency of the word times: 721
# Length of first document: 1842
# Number of words in the first document: 862
# Number of words according to the count vectorizer: 556
# Number of documents the word appears in according to the count vectorizer, use the non-zero elements of the column: 232

# %% [markdown]
# ### Learning word embeddings using LSA

# %%
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(n_components=50, random_state=42)
lsa = svd.fit(doc_term_matrix)

learned_embeddings_lsa = torch.tensor(lsa.components_, device=device)
print(learned_embeddings_lsa.shape)
# Out:
# torch.Size([50, 27103])
